# %%
import matplotlib.pyplot as plt
import pandas as pd

salaries = pd.Series([30000, 27000, 12000, 9500, 19500, 12000, 17000, 14500, 24500, 12000])
plt.hist(salaries)
# Out:
# (array([1., 3., 1., 1., 1., 0., 0., 1., 1., 1.]),
#  array([ 9500., 11550., 13600., 15650., 17700., 19750., 21800., 23850.,
#         25900., 27950., 30000.]),
#  <BarContainer object of 10 artists>)
