# %%
import seaborn as sns
import pandas as pd

salaries = pd.Series([300000, 270000, 120000, 9500, 19500, 12000, 17000, 14500, 24500, 12000])
sns.kdeplot(salaries, shade=True)
# Out:
# /tmp/ipykernel_7240/4171011894.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(salaries, shade=True)
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
import pandas as pd

salaries = pd.Series([300000, 270000, 120000, 9500, 19500, 12000, 17000, 14500, 24500, 12000])
sns.histplot(salaries, kde=True)
# Out:
# <Axes: ylabel='Count'>
