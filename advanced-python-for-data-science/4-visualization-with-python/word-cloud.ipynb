# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

tt = "New New New New New New Narak Narak Narak Narak Narak Narak Narak Digital Digital class class class class Transform dx dx"
mm = WordCloud(width=480, height=480, margin=0).generate(tt)

plt.imshow(mm)
